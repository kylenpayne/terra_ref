# %%
x <- rnorm(10000, mean=10, sd=1)

hist(x)
# Out:
# Plot with title “Histogram of x”

# %%
means<-replicate(100, mean(rnorm(100, mean=10, sd=1)))

# %%
hist(means)
# Out:
# Plot with title “Histogram of means”

# %%
plot(density(x))
lines(density(means))
# Out:
# Plot with title “density.default(x = x)”

# %%
qnorm(.95)
# Out:
# [1] 1.644854
